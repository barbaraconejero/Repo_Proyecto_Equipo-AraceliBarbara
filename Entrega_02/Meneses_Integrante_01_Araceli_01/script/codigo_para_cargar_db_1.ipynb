# %%
import pandas as pd

url = "https://raw.githubusercontent.com/barbaraconejero/Repo_Proyecto_Equipo-AraceliBarbara/refs/heads/main/Entrega_02/Meneses_Integrante_01_Araceli_01/INAPI_database_limpia.csv"
df = pd.read_csv(url, sep=';')
(df.head())
# Out:
#               Marca      Año        Tipo de negocio      Estado     Región
# 0          Columna1  Columna2               Columna3    Columna4  Columna5
# 1     Mister Veggie      2009              Productos  registrada       RM
# 2  Tentación vegana      2015              productos  registrada       RM
# 3         GO! VEGAN      2016  productos y servicios  registrada       RM
# 4       VEGGIEPOPS!      2016              productos  registrada       RM
